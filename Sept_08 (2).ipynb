# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
iris = sns.load_dataset('iris')

# %%
# head; what species are there?
# pairplot and tell me if you see correlation 
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species', palette='coolwarm')

# %%
tips = sns.load_dataset('tips')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.lmplot(x='petal_length',y='petal_width', data=iris)

# %%
sns.lmplot(x='petal_length',y='sepal_length', data=iris)

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# sns lmplot for iris

# learn attributes for 
# titanic = sns.load_dataset('titanic')

# Boxplot for titanic based on class and age
# - what did you learn from it?
# - fill in gaps. predict age where necessary

# Heatmap for titanic data sets

# 911 data set, need counts by 'zip'
# how many unique titles and what are those unique titles? 
# access the value first row of the timeStamp attribute

# %%
sns.boxplot(x="pclass",y="age",palette=["m","g"],data=titanic)
#sns.despine(offset=10, trim=True)

# %%
nine = sns.load_dataset('911')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-cb416582f51f> in <module>
# ----> 1 nine = sns.load_dataset('911')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     593         if not os.path.exists(cache_path):
#     594             if name not in get_dataset_names():
# --> 595                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     596             urlretrieve(url, cache_path)
#     597         full_path = cache_path
#
# ValueError: '911' is not one of the example datasets.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('911.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-b879ff7aee84> in <module>
#       2 import seaborn as sns
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 4 df = pd.read_csv('911.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# 911.csv has 423909 rows in reality, but we are only loading/previewing the first 1000 rows
df1 = pd.read_csv('911.csv', delimiter=',', nrows = nRowsRead)

# %%
df1.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %%
# 911 data set, need counts by 'zip'
# how many unique titles and what are those unique titles? 
# access the value first row of the timeStamp attribute

n = len(pd.unique(df1['title']))
n
# Out:
# 61

# %%
pd.unique(df1['title'])
# Out:
# array(['EMS: BACK PAINS/INJURY', 'EMS: DIABETIC EMERGENCY',
#        'Fire: GAS-ODOR/LEAK', 'EMS: CARDIAC EMERGENCY', 'EMS: DIZZINESS',
#        'EMS: HEAD INJURY', 'EMS: NAUSEA/VOMITING',
#        'EMS: RESPIRATORY EMERGENCY', 'EMS: SYNCOPAL EPISODE',
#        'Traffic: VEHICLE ACCIDENT -', 'EMS: VEHICLE ACCIDENT',
#        'Traffic: DISABLED VEHICLE -', 'Fire: APPLIANCE FIRE',
#        'EMS: GENERAL WEAKNESS', 'Fire: CARBON MONOXIDE DETECTOR',
#        'EMS: UNKNOWN MEDICAL EMERGENCY', 'EMS: UNRESPONSIVE SUBJECT',
#        'Fire: VEHICLE ACCIDENT', 'EMS: ALTERED MENTAL STATUS',
#        'Fire: FIRE ALARM', 'EMS: CVA/STROKE',
#        'Traffic: ROAD OBSTRUCTION -', 'EMS: SUBJECT IN PAIN',
#        'EMS: HEMORRHAGING', 'EMS: FALL VICTIM', 'EMS: ASSAULT VICTIM',
#        'EMS: SEIZURES', 'EMS: MEDICAL ALERT ALARM',
#        'EMS: ABDOMINAL PAINS', 'Fire: PUMP DETAIL',
#        'Fire: FIRE INVESTIGATION', 'EMS: OVERDOSE', 'EMS: MATERNITY',
# ...

# %%
df2 = df1.groupby(['timeStamp','title']).agg(TIME1=pd.NamedAgg(column='timeStamp', aggfunc='min'),
                            TIME2=pd.NamedAgg(column='timeStamp', aggfunc='max'))

print (df2)
# Out:
#                                                                TIME1  \
# timeStamp           title
# 2015-12-10 14:39:21 Fire: GAS-ODOR/LEAK          2015-12-10 14:39:21
# 2015-12-10 15:39:04 EMS: HEAD INJURY             2015-12-10 15:39:04
# 2015-12-10 16:17:05 EMS: RESPIRATORY EMERGENCY   2015-12-10 16:17:05
# 2015-12-10 16:32:10 Traffic: VEHICLE ACCIDENT -  2015-12-10 16:32:10
# 2015-12-10 16:46:48 EMS: NAUSEA/VOMITING         2015-12-10 16:46:48
# ...                                                              ...
# 2015-12-13 10:31:43 Fire: FIRE ALARM             2015-12-13 10:31:43
# 2015-12-13 10:34:30 EMS: MEDICAL ALERT ALARM     2015-12-13 10:34:30
# 2015-12-13 10:35:06 EMS: FALL VICTIM             2015-12-13 10:35:06
# 2015-12-13 10:36:22 EMS: RESPIRATORY EMERGENCY   2015-12-13 10:36:22
# 2015-12-13 10:42:24 EMS: GENERAL WEAKNESS        2015-12-13 10:42:24
#
#                                                                TIME2
# timeStamp           title
# ...

# %%
sns.set_theme(style="white")

# Generate a large random dataset
#rs = np.random.RandomState(33)
#d = pd.DataFrame(data=rs.normal(size=(100, 26)),
#                 columns=list(ascii_letters[26:]))

# Compute the correlation matrix
corr = titanic.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
