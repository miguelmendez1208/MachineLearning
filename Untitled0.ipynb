# %%
# single line comment
''' Multiline Comment
    ajodsjfiasdf
    hello
    testing
'''
' Hello '
1+1

display(2 * 4)

display(2**4)
# Out:
# 8
# 16

# %%
My_Variable = 3

# %%
My_Variable
# Out:
# 3

# %%
z = My_Variable ** 2

# %%
display
# Out:
# <function IPython.core.display.display(*objs, include=None, exclude=None, metadata=None, transient=None, display_id=None, **kwargs)>

# %%
display(z)
# Out:
# 9

# %%
print('Single quotes')
# Out:
# Single quotes

# %%
print("double quotes")
# Out:
# double quotes

# %%
x = 5

# %%
x
# Out:
# 5

# %%
x = 5* 3.6

# %%
x
# Out:
# 18.0

# %%
number = 12
name = 'String'
print("My number is: {}, and the name is: {}".format(number,name))
# Out:
# My number is: 12, and the name is: String

# %%
#lists
y = [1, 2, 3]
y
# Out:
# [1, 2, 3]

# %%
mylist = ['hello', 1, [2,3]]

# %%
mylist
# Out:
# ['hello', 1, [2, 3]]

# %%
mylist.append('xyz')

# %%
mylist
# Out:
# ['hello', 1, [2, 3], 'xyz']

# %%
mylist[1:]
# Out:
# [1, [2, 3], 'xyz']

# %%
mylist[:1]
# Out:
# ['hello']

# %%
mylist[0] = 'Java'

# %%
mylist
# Out:
# ['Java', 1, [2, 3], 'xyz']

# %%
myNestedList = [1,2,3,[4,5,['C++', 'Javaj']]]

# %%
myNestedList
# Out:
# [1, 2, 3, [4, 5, ['C++', 'Javaj']]]

# %%
print(myNestedList[3][2])
# Out:
# ['C++', 'Javaj']

# %%
print(myNestedList[3][2][1])
# Out:
# Javaj

# %%
#dictionary / map
dict = {'key1: 'word1', 'key2' : 'word2'}
dict
# Out:
#   File "<ipython-input-41-8cd45f11e987>", line 2
#     dict = {'key1: 'word1', 'key2' : 'word2'}
#                         ^
# SyntaxError: invalid syntax
